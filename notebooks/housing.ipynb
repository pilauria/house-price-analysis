# %%
#import and read the data
import pandas as pd
df = pd.read_csv('housing.csv')
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ...  Fence Misc Feature Misc Val Mo Sold  \
# 0   NaN       IR1          Lvl  ...    NaN          NaN        0       5
# 1   NaN       Reg          Lvl  ...  MnPrv          NaN        0       6
# 2   NaN       IR1          Lvl  ...    NaN         Gar2    12500       6
# 3   NaN       Reg          Lvl  ...    NaN          NaN        0       4
# 4   NaN       IR1          Lvl  ...  MnPrv          NaN        0       3
#
#   Yr Sold Sale Type Sale Condition SalePrice           Year            Rooms
# ...

# %%
#info about the data
df.info()
#describe the data
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 84 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
# Option 1: Use size for Garage Area and color for Overall Quality
import seaborn as sns

sns.set_theme(style="whitegrid", context="talk")

sns.relplot(data=df, 
           x='Gr Liv Area', 
           y='SalePrice',
           hue='Overall Qual',
           palette='rocket_r',
           size='Garage Area',    # Now size represents garage area
           sizes=(1, 300),       # Adjust size range as needed
           height=8,
           aspect=1.5)

# Option 2: Create a subplot grid to show both relationships
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# First plot: Living Area vs Price
sns.scatterplot(data=df, 
                x='Gr Liv Area', 
                y='SalePrice',
                hue='Overall Qual',
                palette='rocket_r',
                ax=ax1)
ax1.set_title('Price vs Living Area')

# Second plot: Garage Area vs Price
sns.scatterplot(data=df, 
                x='Garage Area', 
                y='SalePrice',
                hue='Overall Qual',
                palette='rocket_r',
                ax=ax2)
ax2.set_title('Price vs Garage Area')

plt.tight_layout()

# %%
sns.set_theme(style="whitegrid", context="talk")

sns.relplot(data=df, 
           x='Gr Liv Area', 
           y='SalePrice',
           hue='Overall Qual',
           palette='rocket_r',
           size='Garage Area',    
           sizes=(20, 400),
           style='Rooms',         # Add different markers based on rooms
           markers={'6 rooms or less': 'o', '7 rooms or more': '^'},  # circle and triangle
           height=8,
           aspect=1.5)

# Add a title
plt.title('House Prices: Living Area, Quality, Garage Size, and Rooms')
# Out:
# Text(0.5, 1.0, 'House Prices: Living Area, Quality, Garage Size, and Rooms')

# %%
# Create a year category (assuming 2000 as the splitting point)
df['Year Category'] = df['Year Built'].apply(lambda x: '2000 or newer' if x >= 2000 else '1999 or older')

# Create two separate plots using FacetGrid
sns.set_theme(style="whitegrid", context="talk")

g = sns.relplot(data=df, 
           x='Gr Liv Area', 
           y='SalePrice',
           hue='Overall Qual',
           palette='rocket_r',
           size='Garage Area',    
           sizes=(20, 400),
           style='Rooms',         
           markers={'6 rooms or less': 'o', '7 rooms or more': '^'},
           col='Year',    # Split plots by Year Category
           height=8,
           aspect=1.2)

# Adjust titles
g.fig.suptitle('House Prices by Age: Living Area, Quality, Garage Size, and Rooms', y=1.05)
# Out:
# Text(0.5, 1.05, 'House Prices by Age: Living Area, Quality, Garage Size, and Rooms')
